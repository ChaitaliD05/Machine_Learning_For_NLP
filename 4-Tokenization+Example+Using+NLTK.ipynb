# %%
# !pip install nltk
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting nltk
#   Using cached nltk-3.9.1-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: click in /home/chaitali/.local/lib/python3.11/site-packages (from nltk) (8.2.1)
# Requirement already satisfied: joblib in /home/chaitali/.local/lib/python3.11/site-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in /home/chaitali/.local/lib/python3.11/site-packages (from nltk) (2025.8.29)
# Requirement already satisfied: tqdm in /home/chaitali/.local/lib/python3.11/site-packages (from nltk) (4.67.1)
# Using cached nltk-3.9.1-py3-none-any.whl (1.5 MB)
# Installing collected packages: nltk
# Successfully installed nltk-3.9.1

# %%
corpus="""Hello Welcome,to Krish Naik's NLP Tutorials.
Please do watch the entire course! to become expert in NLP.
I am Chaitali. I am preparing for interviews.
"""

# %%
print(corpus)
# Out:
# Hello Welcome,to Krish Naik's NLP Tutorials.
# Please do watch the entire course! to become expert in NLP.
# I am Chaitali. I am preparing for interviews.

# %%
##  Tokenization
## Sentence-->paragraphs
from nltk.tokenize import sent_tokenize

# %%
import nltk
nltk.download('punkt_tab')
documents = sent_tokenize(corpus)
print(documents)
# Out:
# ["Hello Welcome,to Krish Naik's NLP Tutorials.", 'Please do watch the entire course!', 'to become expert in NLP.', 'I am Chaitali.', 'I am preparing for interviews.']
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /home/chaitali/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
type(documents)
# Out:
# list

# %%
for sentence in documents:
    print(sentence)
# Out:
# Hello Welcome,to Krish Naik's NLP Tutorials.
# Please do watch the entire course!
# to become expert in NLP.
# I am Chaitali.
# I am preparing for interviews.

# %%
## Tokenization 
## Paragraph-->words
## sentence--->words
from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Krish',
#  'Naik',
#  "'s",
#  'NLP',
#  'Tutorials',
#  '.',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.',
#  'I',
#  'am',
#  'Chaitali',
#  '.',
#  'I',
#  'am',
#  'preparing',
#  'for',
#  'interviews',
#  '.']

# %%
for sentence in documents:
    print(word_tokenize(sentence))
# Out:
# ['Hello', 'Welcome', ',', 'to', 'Krish', 'Naik', "'s", 'NLP', 'Tutorials', '.']
# ['Please', 'do', 'watch', 'the', 'entire', 'course', '!']
# ['to', 'become', 'expert', 'in', 'NLP', '.']
# ['I', 'am', 'Chaitali', '.']
# ['I', 'am', 'preparing', 'for', 'interviews', '.']

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Krish',
#  'Naik',
#  "'",
#  's',
#  'NLP',
#  'Tutorials',
#  '.',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.',
#  'I',
#  'am',
#  'Chaitali',
#  '.',
#  'I',
#  'am',
#  'preparing',
#  'for',
#  'interviews',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer

# %% [markdown]
# #Full stop will not be seperate word

# %%
tokenizer=TreebankWordTokenizer()

# %%
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Krish',
#  'Naik',
#  "'s",
#  'NLP',
#  'Tutorials.',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP.',
#  'I',
#  'am',
#  'Chaitali.',
#  'I',
#  'am',
#  'preparing',
#  'for',
#  'interviews',
#  '.']
